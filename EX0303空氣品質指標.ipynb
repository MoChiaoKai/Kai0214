# %% [markdown]
# <a href="https://colab.research.google.com/github/MoChiaoKai/Kai0214/blob/main/EX0303%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant    status  so2    co    o3  o3_8hr  pm10  \
# 0       基隆    基隆市   51     臭氧八小時        普通  1.2  0.20  54.0    55.0  10.0
# 1       汐止    新北市   74     臭氧八小時        普通  2.8  0.19  62.0    62.0  12.0
# 2       新店    新北市  118     臭氧八小時  對敏感族群不健康  1.2  0.32  92.0    76.0  28.0
# 3       土城    新北市  100     臭氧八小時        普通  1.7  0.35  89.0    70.0   NaN
# 4       板橋    新北市  104     臭氧八小時  對敏感族群不健康  2.1  0.34  85.0    72.0   NaN
#
#    ...  wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg  \
# 0  ...         0.7          34  2025/05/13 15:00:00     0.2       5.2
# 1  ...         1.7          29  2025/05/13 15:00:00     0.2       9.3
# 2  ...         2.9         330  2025/05/13 15:00:00     0.3      15.7
# 3  ...         1.9         330  2025/05/13 15:00:00     0.4      22.0
# 4  ...         3.2         358  2025/05/13 15:00:00     0.4      16.5
#
#   pm10_avg so2_avg   longitude   latitude  siteid
# 0       11       1  121.760056  25.129167       1
# 1       16       0  121.640810  25.066240       2
# 2       25       0  121.537778  24.977222       4
# 3       33       1  121.451861  24.982528       5
# 4       30       1  121.458667  25.012972       6
#
# [5 rows x 24 columns]

# %%
df = df[['sitename', 'county', 'pollutant', 'status', 'aqi']]
df
# Out:
#        sitename county pollutant    status  aqi
# 0            基隆    基隆市     臭氧八小時        普通   51
# 1            汐止    新北市     臭氧八小時        普通   74
# 2            新店    新北市     臭氧八小時  對敏感族群不健康  118
# 3            土城    新北市     臭氧八小時        普通  100
# 4            板橋    新北市     臭氧八小時  對敏感族群不健康  104
# ..          ...    ...       ...       ...  ...
# 81       屏東（琉球）    屏東縣     臭氧八小時        普通  100
# 82  台中市（和平區消防隊）    臺中市       NaN        良好   43
# 83       新北(樹林)    新北市     臭氧八小時  對敏感族群不健康  104
# 84       臺南（南化）    臺南市     臭氧八小時        普通   54
# 85       屏東(枋山)    屏東縣     臭氧八小時  對敏感族群不健康  122
#
# [86 rows x 5 columns]

# %%
condition = df['aqi'] > 100
df[condition]
# Out:
#    sitename county pollutant    status  aqi
# 2        新店    新北市     臭氧八小時  對敏感族群不健康  118
# 4        板橋    新北市     臭氧八小時  對敏感族群不健康  104
# 17       觀音    桃園市        臭氧  對敏感族群不健康  102
# 23       頭份    苗栗縣     臭氧八小時  對敏感族群不健康  101
# 27       沙鹿    臺中市     臭氧八小時  對敏感族群不健康  122
# 32       線西    彰化縣     臭氧八小時  對敏感族群不健康  108
# 33       二林    彰化縣     臭氧八小時  對敏感族群不健康  115
# 35       斗六    雲林縣     臭氧八小時  對敏感族群不健康  101
# 38       朴子    嘉義縣     臭氧八小時  對敏感族群不健康  101
# 44       臺南    臺南市     臭氧八小時  對敏感族群不健康  108
# 70       馬祖    連江縣     臭氧八小時  對敏感族群不健康  108
# 71       金門    金門縣     臭氧八小時  對敏感族群不健康  132
# 72       馬公    澎湖縣     臭氧八小時  對敏感族群不健康  112
# 76       大城    彰化縣     臭氧八小時  對敏感族群不健康  101
# 77       員林    彰化縣     臭氧八小時  對敏感族群不健康  115
# 83   新北(樹林)    新北市     臭氧八小時  對敏感族群不健康  104
# 85   屏東(枋山)    屏東縣     臭氧八小時  對敏感族群不健康  122

# %%
df['pollutant'].unique()
# Out:
# array(['臭氧八小時', '細懸浮微粒', '臭氧', nan], dtype=object)

# %%
condition = df['county'] == '高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 45       美濃    高雄市     臭氧八小時     普通   54
# 46       橋頭    高雄市     臭氧八小時     普通   77
# 47       仁武    高雄市     細懸浮微粒     普通   58
# 48       鳳山    高雄市     臭氧八小時     普通   93
# 49       大寮    高雄市     細懸浮微粒     普通   73
# 50       林園    高雄市     臭氧八小時     普通   80
# 51       楠梓    高雄市     臭氧八小時     普通   71
# 52       左營    高雄市     臭氧八小時     普通   84
# 53       前金    高雄市     臭氧八小時     普通   80
# 54       前鎮    高雄市     臭氧八小時     普通   74
# 55       小港    高雄市     臭氧八小時     普通   71
# 68       復興    高雄市     臭氧八小時     普通   67
# 79   高雄（湖內）    高雄市     臭氧八小時     普通   61

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    132.000000
# 澎湖縣    112.000000
# 連江縣    108.000000
# 彰化縣    105.800000
# 嘉義縣     97.000000
# 苗栗縣     94.666667
# 雲林縣     94.000000
# 屏東縣     93.200000
# 新竹市     93.000000
# 新北市     87.166667
# 新竹縣     87.000000
# 桃園市     86.833333
# 嘉義市     84.000000
# 臺中市     82.333333
# 臺南市     75.600000
# 臺北市     74.000000
# 高雄市     72.538462
# 花蓮縣     54.000000
# 南投縣     52.500000
# 基隆市     51.000000
# 宜蘭縣     48.333333
# 臺東縣     45.500000
# Name: aqi, dtype: float64
